# %%
import pandas as pd
df = pd.read_csv('Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogramme de la variable 'Age'
plt.hist(df['Age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Fréquence')
plt.title('Distribution des âges')
plt.show()


numeric_df = df.select_dtypes(include=['number'])

# Diagramme en barres de la variable 'Gender'
# sns.countplot(numeric_df['Gender'])
# plt.xlabel('Genre')
# plt.ylabel('Nombre de clients')
# plt.title('Répartition des clients par genre')
# plt.show()
# Matrice de corrélation
corr_matrix = numeric_df.corr()
print(corr_matrix)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Matrice de corrélation')
plt.show()
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
print(df.isnull().sum())
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
print(df['Gender'].value_counts())
# Out:
# Gender
# Female    112
# Male       88
# Name: count, dtype: int64

# %% [markdown]
# # prétraitement les données

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Encodage de la variable 'Gender'
label_encoder = LabelEncoder()
df['Gender'] = label_encoder.fit_transform(df['Gender'])

# Normalisation des variables numériques
scaler = StandardScaler()
numeric_columns = ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# Afficher les premières lignes du DataFrame après le prétraitement
print(df.head())
# Out:
#    CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1 -1.424569           -1.738999               -0.434801
# 1           2       1 -1.281035           -1.738999                1.195704
# 2           3       0 -1.352802           -1.700830               -1.715913
# 3           4       0 -1.137502           -1.700830                1.040418
# 4           5       0 -0.563369           -1.662660               -0.395980

# %% [markdown]
# # Choix du nombre de clusters (K)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Créer une liste vide pour stocker les valeurs d'inertie et de coefficient de silhouette
inertia_values = []
silhouette_scores = []

# Définir une plage de valeurs de K
k_range = range(2, 11)

# Boucle sur les différentes valeurs de K
for k in k_range:
    # Créer le modèle K-means
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df)
    
    # Calculer l'inertie et l'ajouter à la liste
    inertia_values.append(kmeans.inertia_)
    
    # Calculer le coefficient de silhouette et l'ajouter à la liste
    silhouette_scores.append(silhouette_score(df, kmeans.labels_))

# Tracer le graphique de l'inertie en fonction de K
plt.figure(figsize=(10, 5))
plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Nombre de clusters (K)')
plt.ylabel('Inertie')
plt.title('Méthode du coude')
plt.show()

# Tracer le graphique du coefficient de silhouette en fonction de K
plt.figure(figsize=(8, 5))
plt.plot(k_range, silhouette_scores, marker='o')
plt.xlabel('Nombre de clusters (K)')
plt.ylabel('Coefficient de silhouette')
plt.title('Coefficient de silhouette')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# # Age & Spending Score (1-100)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Définir une plage de valeurs de K
k_range = range(1, 11)

X1 = df[['Age' , 'Spending Score (1-100)']].iloc[: , :].values
# Créer une liste vide pour stocker les valeurs d'inertie
inertia_values = []

# Boucler sur les différentes valeurs de K
for k in k_range:
    # Créer le modèle K-means
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X1)
    
    # Calculer et stocker l'inertie
    inertia_values.append(kmeans.inertia_)

# Tracer le graphique de l'inertie en fonction de K
plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Nombre de clusters (K)')
plt.ylabel('Inertie')
plt.title('Méthode du coude')
plt.xticks(k_range)
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# Définir le nombre de clusters (K)
k = 4

# Sélectionner les caractéristiques à utiliser
features = ['Age', 'Spending Score (1-100)']
X = df[features]

# Créer le modèle K-means avec le nombre de clusters spécifié
kmeans = KMeans(n_clusters=k, random_state=42)

# Entraîner le modèle sur les données
kmeans.fit(X)

# Déterminer les limites de la grille
x_min, x_max = X['Age'].min() - 1, X['Age'].max() + 1
y_min, y_max = X['Spending Score (1-100)'].min() - 1, X['Spending Score (1-100)'].max() + 1

# Générer une grille de points pour la visualisation
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# Prédire les clusters pour chaque point de la grille
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

# Mettre en forme les données pour la visualisation
Z = Z.reshape(xx.shape)

# Afficher le graphique avec les régions colorées par cluster
plt.figure(figsize=(10, 6))
plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['Age'], X['Spending Score (1-100)'], c=kmeans.labels_, s=20, cmap='viridis')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.title('Clusters K-means')
plt.colorbar()
plt.show()

# %%
CustomerID                0
Gender                    0
Age                       0
Annual Income (k$)        0
Spending Score (1-100)

# %% [markdown]
# # Age & Annual Income

# %%
df
# Out:
#      CustomerID  Gender       Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1       1 -1.424569           -1.738999               -0.434801
# 1             2       1 -1.281035           -1.738999                1.195704
# 2             3       0 -1.352802           -1.700830               -1.715913
# 3             4       0 -1.137502           -1.700830                1.040418
# 4             5       0 -0.563369           -1.662660               -0.395980
# ..          ...     ...       ...                 ...                     ...
# 195         196       0 -0.276302            2.268791                1.118061
# 196         197       0  0.441365            2.497807               -0.861839
# 197         198       1 -0.491602            2.497807                0.923953
# 198         199       1 -0.491602            2.917671               -1.250054
# 199         200       1 -0.635135            2.917671                1.273347
#
#      Cluster
# 0          0
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Définir une plage de valeurs de K
k_range = range(1, 11)

X1 = df[['Age' , 'Annual Income (k$)']].iloc[: , :].values
# Créer une liste vide pour stocker les valeurs d'inertie
inertia_values = []

# Boucler sur les différentes valeurs de K
for k in k_range:
    # Créer le modèle K-means
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X1)
    
    # Calculer et stocker l'inertie
    inertia_values.append(kmeans.inertia_)

# Tracer le graphique de l'inertie en fonction de K
plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Nombre de clusters (K)')
plt.ylabel('Inertie')
plt.title('Méthode du coude')
plt.xticks(k_range)
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# Définir le nombre de clusters (K)
k = 3

# Sélectionner les caractéristiques à utiliser
features = ['Age', 'Annual Income (k$)']
X = df[features]

# Créer le modèle K-means avec le nombre de clusters spécifié
kmeans = KMeans(n_clusters=k, random_state=42)

# Entraîner le modèle sur les données
kmeans.fit(X)

# Déterminer les limites de la grille
x_min, x_max = X['Age'].min() - 1, X['Age'].max() + 1
y_min, y_max = X['Annual Income (k$)'].min() - 1, X['Annual Income (k$)'].max() + 1

# Générer une grille de points pour la visualisation
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# Prédire les clusters pour chaque point de la grille
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

# Mettre en forme les données pour la visualisation
Z = Z.reshape(xx.shape)

# Afficher le graphique avec les régions colorées par cluster
plt.figure(figsize=(10, 6))
plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['Age'], X['Annual Income (k$)'], c=kmeans.labels_, s=20, cmap='viridis')
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.title('Clusters K-means')
plt.colorbar()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Annual Income (k$) & Spending Score (1-100)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Définir une plage de valeurs de K
k_range = range(1, 11)

X1 = df[['Annual Income (k$)' , 'Spending Score (1-100)']].iloc[: , :].values
# Créer une liste vide pour stocker les valeurs d'inertie
inertia_values = []

# Boucler sur les différentes valeurs de K
for k in k_range:
    # Créer le modèle K-means
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X1)
    
    # Calculer et stocker l'inertie
    inertia_values.append(kmeans.inertia_)

# Tracer le graphique de l'inertie en fonction de K
plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Nombre de clusters (K)')
plt.ylabel('Inertie')
plt.title('Méthode du coude')
plt.xticks(k_range)
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# Définir le nombre de clusters (K)
k = 3

# Sélectionner les caractéristiques à utiliser
features = ['Annual Income (k$)', 'Spending Score (1-100)']
X = df[features]

# Créer le modèle K-means avec le nombre de clusters spécifié
kmeans = KMeans(n_clusters=k, random_state=42)

# Entraîner le modèle sur les données
kmeans.fit(X)

# Déterminer les limites de la grille
x_min, x_max = X['Annual Income (k$)'].min() - 1, X['Annual Income (k$)'].max() + 1
y_min, y_max = X['Spending Score (1-100)'].min() - 1, X['Spending Score (1-100)'].max() + 1

# Générer une grille de points pour la visualisation
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# Prédire les clusters pour chaque point de la grille
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

# Mettre en forme les données pour la visualisation
Z = Z.reshape(xx.shape)

# Afficher le graphique avec les régions colorées par cluster
plt.figure(figsize=(10, 6))
plt.contourf(xx, yy, Z, alpha=0.4)
plt.scatter(X['Annual Income (k$)'], X['Spending Score (1-100)'], c=kmeans.labels_, s=20, cmap='viridis')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Clusters K-means')
plt.colorbar()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Age  Annual Income (k$)  Spending Score (1-100)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Définir une plage de valeurs de K
k_range = range(1, 11)

X1 = df[['Age', 'Annual Income (k$)' , 'Spending Score (1-100)']].iloc[: , :].values
# Créer une liste vide pour stocker les valeurs d'inertie
inertia_values = []

# Boucler sur les différentes valeurs de K
for k in k_range:
    # Créer le modèle K-means
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X1)
    
    # Calculer et stocker l'inertie
    inertia_values.append(kmeans.inertia_)

# Tracer le graphique de l'inertie en fonction de K
plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Nombre de clusters (K)')
plt.ylabel('Inertie')
plt.title('Méthode du coude')
plt.xticks(k_range)
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Sélection des colonnes pour le clustering
X = df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].values

# Définition du nombre de clusters
k = 4

# Création du modèle K-means
kmeans = KMeans(n_clusters=k, random_state=42)

# Entraînement du modèle sur les données
kmeans.fit(X)

# Ajout des informations sur les clusters au DataFrame
df['Cluster'] = kmeans.labels_

# Affichage des centres des clusters
print("Centroids:")
print(kmeans.cluster_centers_)

# Visualisation des clusters
plt.figure(figsize=(10, 6))

# Parcourez chaque cluster et affichez les points correspondants
for cluster in range(k):
    plt.scatter(X[df['Cluster'] == cluster, 0], X[df['Cluster'] == cluster, 1], label=f'Cluster {cluster}')

# Affichage des centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label='Centroids')

plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.title('Clustering des clients')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Centroids:
# [[ 1.08616125 -0.49056525 -0.39717443]
#  [-0.42880597  0.97484722  1.21608539]
#  [-0.96249203 -0.78476346  0.39202966]
#  [ 0.03720536  0.99011499 -1.18875705]]

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Sélection des colonnes pour le clustering
X = df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].values

# Définition du nombre optimal de clusters
k = 5

# Création du modèle K-means
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X)

# Prédictions des clusters pour chaque point de données
labels = kmeans.labels_

# Tracé du graphique en utilisant les deux premières dimensions avec une palette de couleurs spécifique
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', data=df, hue=labels, palette='tab10')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='o', label='Centroids')
plt.title('Clusters des clients en fonction de leur revenu annuel et de leur score de dépenses')
plt.xlabel('Revenu annuel (k$)')
plt.ylabel('Score de dépenses (1-100)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.cluster import KMeans

# Importation des données
df = pd.read_csv('Mall_Customers.csv')

# Sélection des caractéristiques pour le clustering
X = df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].values

# Application de la méthode du coude pour déterminer le nombre optimal de clusters
inertia = []
for n in range(1, 11):
    kmeans = KMeans(n_clusters=n, init='k-means++', random_state=0)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

# Tracé du graphique de la méthode du coude
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Méthode du coude')
plt.xlabel('Nombre de clusters')
plt.ylabel('Inertie')
plt.show()

# Application du modèle K-means avec le nombre optimal de clusters
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=0)
y_kmeans = kmeans.fit_predict(X)

# Visualisation des clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=100, c='cyan', label='Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s=100, c='magenta', label='Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids')
plt.title('Clusters des clients')
plt.xlabel('Age')
plt.ylabel('Revenu annuel (k$)')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# # Entraînement du modèle K-means

# %%
from sklearn.cluster import KMeans

# Utiliser le nombre optimal de clusters K choisi à l'étape précédente
optimal_k = 3

# Créer le modèle K-means avec le nombre optimal de clusters
kmeans_model = KMeans(n_clusters=optimal_k, random_state=42)

# Entraîner le modèle sur les données
kmeans_model.fit(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
# Prédire les clusters pour chaque client
clusters = kmeans_model.predict(df)

# Ajouter les informations des clusters dans le DataFrame
df['Cluster'] = clusters

# Afficher le DataFrame avec les informations sur les clusters
print(df)
# Out:
#      Gender       Age  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0         1 -1.424569           -1.738999               -0.434801        0
# 1         1 -1.281035           -1.738999                1.195704        0
# 2         0 -1.352802           -1.700830               -1.715913        0
# 3         0 -1.137502           -1.700830                1.040418        0
# 4         0 -0.563369           -1.662660               -0.395980        0
# ..      ...       ...                 ...                     ...      ...
# 195       0 -0.276302            2.268791                1.118061        2
# 196       0  0.441365            2.497807               -0.861839        1
# 197       1 -0.491602            2.497807                0.923953        2
# 198       1 -0.491602            2.917671               -1.250054        2
# 199       1 -0.635135            2.917671                1.273347        2
#
# [200 rows x 5 columns]

# %%
plt.figure(1 , figsize = (15 , 5))
sns.countplot(y = 'Gender' , data = df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Tracer un nuage de points en utilisant les caractéristiques Age et Annual Income, en colorant les points selon les clusters
sns.scatterplot(x='Age', y='Annual Income (k$)', hue='Cluster', data=df, palette='tab10')
plt.title('Clusters based on Age and Annual Income')
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.legend(title='Cluster')
plt.show()

# Tracer un nuage de points en utilisant les caractéristiques Age et Spending Score, en colorant les points selon les clusters
sns.scatterplot(x='Age', y='Spending Score (1-100)', hue='Cluster', data=df, palette='tab10')
plt.title('Clusters based on Age and Spending Score')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.legend(title='Cluster')
plt.show()

# Tracer un nuage de points en utilisant les caractéristiques Annual Income et Spending Score, en colorant les points selon les clusters
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=df, palette='tab10')
plt.title('Clusters based on Annual Income and Spending Score')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend(title='Cluster')
plt.show()
